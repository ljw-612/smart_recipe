# %%
from langchain_community.llms.llamafile import Llamafile

# %%
llm = Llamafile()

llm.invoke("你好")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 llm = Llamafile()
# ----> 3 llm.invoke("你好")
#
# File ~/miniforge3/envs/rag_590/lib/python3.8/site-packages/langchain_core/language_models/llms.py:273, in invoke(self, input, config, stop, **kwargs)
#     260     else:
#     261         raise ValueError(
#     262             f"Invalid input type {type(input)}. "
#     263             "Must be a PromptValue, str, or list of BaseMessages."
#     264         )
#     266 def invoke(
#     267     self,
#     268     input: LanguageModelInput,
#     269     config: Optional[RunnableConfig] = None,
#     270     *,
#     271     stop: Optional[List[str]] = None,
#     272     **kwargs: Any,
# --> 273 ) -> str:
#     274     config = ensure_config(config)
#     275     return (
#     276         self.generate_prompt(
# ...
