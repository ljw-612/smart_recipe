# %%
import layoutparser as lp
import cv2

# %%
model = lp.AutoLayoutModel('lp://EfficientDete/PubLayNet')

# %%
import urllib.request


image = cv2.imread("paper-image.jpg")
image = image[..., ::-1]

model = lp.Detectron2LayoutModel('lp://HJDataset/faster_rcnn_R_50_FPN_3x/config',
                                 extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
                                 label_map={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"})
# Out:
# config.yml?dl=1: 0.00B [00:00, ?B/s]
# config.yml?dl=1: 0.00B [01:18, ?B/s]
# Failed to download https://www.dropbox.com/s/j4yseny2u0hn22r/config.yml?dl=1
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1353 try:
# -> 1354     h.request(req.get_method(), req.selector, req.data, headers,
#    1355               encode_chunked=req.has_header('Transfer-encoding'))
#    1356 except OSError as err: # timeout error
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/http/client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/http/client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/http/client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/http/client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/http/client.py:1418, in HTTPSConnection.connect(self)
#    1416 "Connect to a host on a given (SSL) port."
# -> 1418 super().connect()
#    1420 if self._tunnel_host:
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/http/client.py:922, in HTTPConnection.connect(self)
#     921 """Connect to the host and port specified in __init__."""
# --> 922 self.sock = self._create_connection(
#     923     (self.host,self.port), self.timeout, self.source_address)
#     924 self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/socket.py:808, in create_connection(address, timeout, source_address)
#     807 try:
# --> 808     raise err
#     809 finally:
#     810     # Break explicitly a reference cycle
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/socket.py:796, in create_connection(address, timeout, source_address)
#     795     sock.bind(source_address)
# --> 796 sock.connect(sa)
#     797 # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       1 image = cv2.imread("paper-image.jpg")
#       2 image = image[..., ::-1]
# ----> 4 model = lp.Detectron2LayoutModel('lp://HJDataset/faster_rcnn_R_50_FPN_3x/config',
#       5                                  extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
#       6                                  label_map={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"})
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/layoutparser/models/detectron2/layoutmodel.py:91, in Detectron2LayoutModel.__init__(self, config_path, model_path, label_map, extra_config, enforce_cpu, device)
#      86     extra_config = []
#      88 config_path, model_path = self.config_parser(
#      89     config_path, model_path, allow_empty_path=True
#      90 )
# ---> 91 config_path = PathManager.get_local_path(config_path)
#      93 if label_map is None:
#      94     if config_path.startswith("lp://"):
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/iopath/common/file_io.py:1197, in PathManager.get_local_path(self, path, force, **kwargs)
#    1195 handler = self.__get_path_handler(path)  # type: ignore
#    1196 try:
# -> 1197     bret = handler._get_local_path(path, force=force, **kwargs)
#    1198 except TypeError:
#    1199     bret = handler._get_local_path(path, **kwargs)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/layoutparser/models/detectron2/catalog.py:136, in LayoutParserDetectron2ModelHandler._get_local_path(self, path, **kwargs)
#     134 else:
#     135     raise ValueError(f"Unknown data_type {data_type}")
# --> 136 return PathManager.get_local_path(model_url, **kwargs)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/iopath/common/file_io.py:1197, in PathManager.get_local_path(self, path, force, **kwargs)
#    1195 handler = self.__get_path_handler(path)  # type: ignore
#    1196 try:
# -> 1197     bret = handler._get_local_path(path, force=force, **kwargs)
#    1198 except TypeError:
#    1199     bret = handler._get_local_path(path, **kwargs)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/iopath/common/file_io.py:797, in HTTPURLHandler._get_local_path(self, path, force, cache_dir, **kwargs)
#     795     if not os.path.isfile(cached):
#     796         logger.info("Downloading {} ...".format(path))
# --> 797         cached = download(path, dirname, filename=filename)
#     798 logger.info("URL {} cached in {}".format(path, cached))
#     799 self.cache_map[path] = cached
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/site-packages/iopath/common/download.py:58, in download(url, dir, filename, progress)
#      53         return inner
#      55     with tqdm.tqdm(  # type: ignore
#      56         unit="B", unit_scale=True, miniters=1, desc=filename, leave=True
#      57     ) as t:
# ---> 58         tmp, _ = request.urlretrieve(url, filename=tmp, reporthook=hook(t))
#      60 else:
#      61     tmp, _ = request.urlretrieve(url, filename=tmp)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:247, in urlretrieve(url, filename, reporthook, data)
#     230 """
#     231 Retrieve a URL into a temporary location on disk.
#     232
#    (...)
#     243 data file as well as the resulting HTTPMessage object.
#     244 """
#     245 url_type, path = _splittype(url)
# --> 247 with contextlib.closing(urlopen(url, data)) as fp:
#     248     headers = fp.info()
#     250     # Just return the local path and the "headers" for file://
#     251     # URLs. No sense in performing a copy unless requested.
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File ~/miniforge3/envs/pytorch_m1/lib/python3.8/urllib/request.py:1357, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1354         h.request(req.get_method(), req.selector, req.data, headers,
#    1355                   encode_chunked=req.has_header('Transfer-encoding'))
#    1356     except OSError as err: # timeout error
# -> 1357         raise URLError(err)
#    1358     r = h.getresponse()
#    1359 except:
#
# URLError: <urlopen error [Errno 60] Operation timed out>
